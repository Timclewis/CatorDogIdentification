# %%
import tensorflow as tf
import keras as k

from keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers
from tensorflow.keras.models import Model, load_model

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random as r
import numpy as np

if tf.test.gpu_device_name():
    print('GPU avaliable {}'.format(tf.test.gpu_device_name()))
else:
    print('Please install GPU version of TF')
# Out:
# GPU avaliable /device:GPU:0

# %%
PATH_TRAIN = "C:/Users/crims/Tensorflow/Practice/cats-v-dogs/training_set/"
PATH_TEST = "C:/Users/crims/Tensorflow/Practice/cats-v-dogs/testing/"

data_gen = ImageDataGenerator(rescale=1.0/255, validation_split=0.2)
data_gen_test = ImageDataGenerator(rescale=1.0/255)
train_data = data_gen.flow_from_directory(PATH_TRAIN, target_size=(224, 224), class_mode='binary', 
                                                    batch_size=48, subset='training')

valid_data = data_gen.flow_from_directory(PATH_TRAIN, target_size=(224, 224), class_mode='binary', 
                                                    batch_size=48, subset='validation')

test_data = data_gen_test.flow_from_directory(PATH_TEST, target_size=(224, 224), class_mode=None,
                                                    batch_size=1, shuffle=False)
# Out:
# Found 6404 images belonging to 2 classes.
# Found 1601 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.

# %%
base = ResNet50(include_top=False, weights='imagenet', input_shape=(224,224,3), pooling='avg')
x = base.output
x = layers.Dropout(0.5)(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(1, activation='sigmoid')(x)
resnet50 = Model(base.input, x)

resnet50.compile(loss='binary_crossentropy', metrics=['acc'], optimizer='RMSprop')

resnet50.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
history = resnet50.fit(train_data, epochs=10,
                    validation_data=valid_data)

resnet50.save('resnet50_catvdogmodel')
# Out:
# Epoch 1/10
# 134/134 [==============================] - 74s 473ms/step - loss: 0.7872 - acc: 0.6271 - val_loss: 34.9134 - val_acc: 0.5003
# Epoch 2/10
# 134/134 [==============================] - 62s 461ms/step - loss: 0.4300 - acc: 0.8140 - val_loss: 2.6724 - val_acc: 0.4997
# Epoch 3/10
# 134/134 [==============================] - 62s 462ms/step - loss: 0.3379 - acc: 0.8749 - val_loss: 1.9484 - val_acc: 0.4997
# Epoch 4/10
# 134/134 [==============================] - 62s 462ms/step - loss: 0.2277 - acc: 0.9129 - val_loss: 1.3592 - val_acc: 0.4997
# Epoch 5/10
# 134/134 [==============================] - 62s 464ms/step - loss: 0.1717 - acc: 0.9338 - val_loss: 0.8175 - val_acc: 0.5453
# Epoch 6/10
# 134/134 [==============================] - 62s 462ms/step - loss: 0.1438 - acc: 0.9458 - val_loss: 1.6321 - val_acc: 0.5334
# Epoch 7/10
# 134/134 [==============================] - 62s 461ms/step - loss: 0.1229 - acc: 0.9525 - val_loss: 2.1858 - val_acc: 0.5784
# Epoch 8/10
# ...

# %%
plt.figure(figsize=(14, 8))
plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(122)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Predicting images

n = r.randint(1,2022)
filenames = test_data.filenames
path = f'C:/Users/crims/Tensorflow/Practice/cats-v-dogs/testing/{filenames[n]}'
pic = mpimg.imread(path)
plt.imshow(pic)
plt.show()

img = tf.keras.preprocessing.image.load_img(path, target_size=(224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_batch = np.expand_dims(img_array, axis=0)
img_preprocessed = tf.keras.applications.resnet50.preprocess_input(img_batch)


saved_model = tf.keras.models.load_model('resnet50_catvdogmodel')
classifications = saved_model.predict(img_preprocessed)

#predict = resnet50.predict(img_preprocessed)

print(classifications)

if classifications[0]>0.5:
    print(path + " is a dog")
else:
    print(path + " is a cat")
# Out:
# [[1.]]
# C:/Users/crims/Tensorflow/Practice/cats-v-dogs/testing/dogs\dog.4410.jpg is a dog
