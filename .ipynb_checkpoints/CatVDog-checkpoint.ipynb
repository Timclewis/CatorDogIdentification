# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop

import os
import random as r
from shutil import copyfile
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print('Please install GPU version of TF')
# Out:
# Default GPU Device: /device:GPU:0

# %%
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
    files = []
    for filename in os.listdir(SOURCE):
        file = SOURCE + filename
        if os.path.getsize(file) > 0:
            files.append(filename)
        else:
            print(filename , 'is zero length, so ignore')
            
    training_length = int(len(files) * SPLIT_SIZE)
    testing_length = int(len(files) - training_length)
    shuffled_set = random.sample(files, len(files))
    training_set = shuffled_set[0:training_length]
    testing_set = shuffled_set[-testing_length:]

    for filename in training_set:
        this_file = SOURCE + filename
        destination = TRAINING + filename
        copyfile(this_file, destination)

    for filename in testing_set:
        this_file = SOURCE + filename
        destination = TESTING + filename
        copyfile(this_file, destination)
    
CAT_SOURCE_DIR = "C:/Users/crims/Tensorflow/PetImages/Cat/"
TRAINING_CATS_DIR = "C:/Users/crims/Tensorflow/cats-v-dogs/training/cats/"
TESTING_CATS_DIR = "C:/Users/crims/Tensorflow/cats-v-dogs/testing/cats/"
DOG_SOURCE_DIR = "C:/Users/crims/Tensorflow/PetImages/Dog/"
TRAINING_DOGS_DIR = "C:/Users/crims/Tensorflow/cats-v-dogs/training/dogs/"
TESTING_DOGS_DIR = "C:/Users/crims/Tensorflow/cats-v-dogs/testing/dogs/"    

split_size = .8
split_data(CAT_SOURCE_DIR, TRAINING_CATS_DIR, TESTING_CATS_DIR, split_size)
split_data(DOG_SOURCE_DIR, TRAINING_DOGS_DIR, TESTING_DOGS_DIR, split_size)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-332e9711b4c4> in <module>
#      32
#      33 split_size = .8
# ---> 34 split_data(CAT_SOURCE_DIR, TRAINING_CATS_DIR, TESTING_CATS_DIR, split_size)
#      35 split_data(DOG_SOURCE_DIR, TRAINING_DOGS_DIR, TESTING_DOGS_DIR, split_size)
#      36
#
# <ipython-input-3-332e9711b4c4> in split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE)
#       1 def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
#       2     files = []
# ----> 3     for filename in os.listdir(SOURCE):
#       4         file = SOURCE + filename
#       5         if os.path.getsize(file) > 0:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/crims/Tensorflow/PetImages/Cat/'

# %%
print(len(os.listdir('C:/Users/crims/Tensorflow/cats-v-dogs/training/cats/')))
print(len(os.listdir('C:/Users/crims/Tensorflow/cats-v-dogs/training/dogs/')))
print(len(os.listdir('C:/Users/crims/Tensorflow/cats-v-dogs/testing/cats/')))
print(len(os.listdir('C:/Users/crims/Tensorflow/cats-v-dogs/testing/dogs/')))
# Out:
# 12500
# 12500
# 9234
# 9226

# %%
TRAINING_DIR = "C:/Users/crims/Tensorflow/cats-v-dogs/training/"
train_datagen = ImageDataGenerator(rescale=1.0/255.)
train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                    batch_size=250,
                                                    class_mode='binary',
                                                    target_size=(150, 150))

VALIDATION_DIR = "C:/Users/crims/Tensorflow/cats-v-dogs/testing/"
validation_datagen = ImageDataGenerator(rescale=1.0/255.)
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                              batch_size=250,
                                                              class_mode='binary',
                                                              target_size=(150, 150))
# Out:
# Found 24998 images belonging to 2 classes.
# Found 18458 images belonging to 2 classes.

# %%
model = keras.Sequential([
    layers.Conv2D(16, (3,3), activation='relu', input_shape=(150,150,3)),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

resnet50 = tf.keras.applications.ResNet50(include_top=True, weights=None, 
                                          input_shape=(224,224,3), classes=3)

resnet50.compile(optimizer='rmsprop', loss = 'binary_crossentropy', metrics=['acc'])
history = resnet50.fit(train_generator, epochs=15, steps_per_epoch=90,
                    validation_data=validation_generator, validation_steps=6)
resnet50.save('resnet50_catvdogmodel')
resnet50.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0e25a8dd11ba> in <module>
# ----> 1 model = keras.Sequential([
#       2     layers.Conv2D(16, (3,3), activation='relu', input_shape=(150,150,3)),
#       3     layers.MaxPooling2D(2,2),
#       4     layers.Conv2D(32, (3,3), activation='relu'),
#       5     layers.MaxPooling2D(2,2),
#
# NameError: name 'keras' is not defined

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['acc']
val_acc=history.history['val_acc']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.figure(figsize=(12, 8))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-77b15e7b90ce> in <module>
#       3 # sets for each training epoch
#       4 #-----------------------------------------------------------
# ----> 5 acc=history.history['acc']
#       6 val_acc=history.history['val_acc']
#       7 loss=history.history['loss']
#
# NameError: name 'history' is not defined

# %%
import numpy as np
import matplotlib.image  as mpimg
from keras.preprocessing import image
import random as r

saved_model = keras.models.load_model('my_catvdogmodel')
# predicting images
pic = r.randint(1,95)
path = f'C:/Users/crims/Tensorflow/cats-v-dogs/personal/test ({pic}).jpg'
pic = mpimg.imread(path)
plt.imshow(pic)
plt.show()
img = image.load_img(path, target_size=(150, 150))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = saved_model.predict(images, batch_size=1)
print(classes[0])
if classes[0]>0.5:
    print(path + " is a dog")
else:
    print(path + " is a cat")
# Out:
# [1.]
# C:/Users/crims/Tensorflow/cats-v-dogs/personal/test (73).jpg is a dog
